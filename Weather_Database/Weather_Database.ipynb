# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import sys
# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1e350fe40c563a41f286e243836957ba

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
test_url = url + "&q=" + cities[0].replace(" ","+")
test_weather = requests.get(test_url).json()
test_des = test_weather["weather"][0]["description"]
print(test_des)
# Out:
# clear sky

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(10)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | kuusamo
# Processing Record 3 of Set 1 | gladstone
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | whitehorse
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | san andres
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | goderich
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | auki
# Processing Record 18 of Set 1 | arrifes
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | kruisfontein
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | mount gambier
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | anito
# Processing Record 28 of Set 1 | carutapera
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | karratha
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | ulagan
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | ribeira grande
# Processing Record 35 of Set 1 | san cristobal
# Processing Record 36 of Set 1 | bubaque
# Processing Record 37 of Set 1 | antalaha
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | kachiry
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | nago
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | leeuwarden
# Processing Record 1 of Set 2 | kahului
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | esperance
# Processing Record 4 of Set 2 | muros
# Processing Record 5 of Set 2 | genhe
# Processing Record 6 of Set 2 | asau
# Processing Record 7 of Set 2 | bowling green
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | vao
# Processing Record 10 of Set 2 | makubetsu
# Processing Record 11 of Set 2 | santiago del estero
# Processing Record 12 of Set 2 | kavaratti
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | marystown
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | pucallpa
# Processing Record 22 of Set 2 | merritt island
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | fairbanks
# Processing Record 25 of Set 2 | lorengau
# Processing Record 26 of Set 2 | comodoro rivadavia
# Processing Record 27 of Set 2 | dunedin
# Processing Record 28 of Set 2 | morehead
# Processing Record 29 of Set 2 | honiara
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | alofi
# Processing Record 32 of Set 2 | kamenka
# Processing Record 33 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | katsuura
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | fortuna
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | roma
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | chalmette
# Processing Record 45 of Set 2 | luwuk
# Processing Record 46 of Set 2 | salinopolis
# Processing Record 47 of Set 2 | nola
# Processing Record 48 of Set 2 | maldonado
# Processing Record 49 of Set 2 | qasigiannguit
# Processing Record 50 of Set 2 | acapulco
# Processing Record 1 of Set 3 | yerbogachen
# Processing Record 2 of Set 3 | puerto baquerizo moreno
# Processing Record 3 of Set 3 | washington
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | belen
# Processing Record 6 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 3 | correntina
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | paita
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | port hardy
# Processing Record 12 of Set 3 | brae
# Processing Record 13 of Set 3 | ocampo
# Processing Record 14 of Set 3 | atuona
# Processing Record 15 of Set 3 | litovko
# Processing Record 16 of Set 3 | tautira
# Processing Record 17 of Set 3 | moussoro
# Processing Record 18 of Set 3 | san patricio
# Processing Record 19 of Set 3 | gisborne
# Processing Record 20 of Set 3 | ahipara
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | mwinilunga
# Processing Record 23 of Set 3 | soyo
# Processing Record 24 of Set 3 | dolores
# Processing Record 25 of Set 3 | blairmore
# Processing Record 26 of Set 3 | new norfolk
# Processing Record 27 of Set 3 | sibolga
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | mareeba
# Processing Record 31 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 3 | sabya
# Processing Record 33 of Set 3 | lotoshino
# Processing Record 34 of Set 3 | meulaboh
# Processing Record 35 of Set 3 | deoband
# Processing Record 36 of Set 3 | avera
# Processing Record 37 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | suntar
# Processing Record 41 of Set 3 | seymchan
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | hilo
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | emba
# Processing Record 46 of Set 3 | jumla
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | nishihara
# Processing Record 49 of Set 3 | thompson
# Processing Record 50 of Set 3 | bondoukou
# Processing Record 1 of Set 4 | manggar
# Processing Record 2 of Set 4 | miri
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | rayadrug
# Processing Record 7 of Set 4 | mehran
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | muriwai beach
# Processing Record 10 of Set 4 | xingyi
# Processing Record 11 of Set 4 | magog
# Processing Record 12 of Set 4 | barra do garcas
# Processing Record 13 of Set 4 | dubenskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | mazsalaca
# Processing Record 15 of Set 4 | bjornevatn
# Processing Record 16 of Set 4 | henties bay
# Processing Record 17 of Set 4 | padang
# Processing Record 18 of Set 4 | nsanje
# Processing Record 19 of Set 4 | janow lubelski
# Processing Record 20 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | flinders
# Processing Record 22 of Set 4 | parambu
# Processing Record 23 of Set 4 | nalut
# Processing Record 24 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | palmer
# Processing Record 28 of Set 4 | gunzenhausen
# Processing Record 29 of Set 4 | khatanga
# Processing Record 30 of Set 4 | dikson
# Processing Record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | deputatskiy
# Processing Record 34 of Set 4 | ishinomaki
# Processing Record 35 of Set 4 | bereda
# Processing Record 36 of Set 4 | necochea
# Processing Record 37 of Set 4 | smithville
# Processing Record 38 of Set 4 | inhambane
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | pacific grove
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | leningradskiy
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | ixtapa
# Processing Record 46 of Set 4 | rocha
# Processing Record 47 of Set 4 | bissau
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | bilaspur
# Processing Record 50 of Set 4 | moron
# Processing Record 1 of Set 5 | anadyr
# Processing Record 2 of Set 5 | inirida
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | petropavlivka
# Processing Record 5 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 5 | maxixe
# Processing Record 7 of Set 5 | thunder bay
# Processing Record 8 of Set 5 | yulara
# Processing Record 9 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 5 | nosy varika
# Processing Record 11 of Set 5 | half moon bay
# Processing Record 12 of Set 5 | buala
# Processing Record 13 of Set 5 | ulaangom
# Processing Record 14 of Set 5 | moyamba
# Processing Record 15 of Set 5 | cayenne
# Processing Record 16 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 5 | irece
# Processing Record 18 of Set 5 | puerto maldonado
# Processing Record 19 of Set 5 | nichinan
# Processing Record 20 of Set 5 | wanning
# Processing Record 21 of Set 5 | kuminskiy
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | bayangol
# Processing Record 26 of Set 5 | sierpc
# Processing Record 27 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | coahuayana
# Processing Record 30 of Set 5 | touros
# Processing Record 31 of Set 5 | fare
# Processing Record 32 of Set 5 | kingsville
# Processing Record 33 of Set 5 | grootegast
# Processing Record 34 of Set 5 | souillac
# Processing Record 35 of Set 5 | mao
# Processing Record 36 of Set 5 | olafsvik
# Processing Record 37 of Set 5 | pathalgaon
# Processing Record 38 of Set 5 | kirakira
# Processing Record 39 of Set 5 | kalakamati
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | faanui
# Processing Record 42 of Set 5 | gidole
# Processing Record 43 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 44 of Set 5 | novikovo
# Processing Record 45 of Set 5 | kenai
# Processing Record 46 of Set 5 | norrkoping
# Processing Record 47 of Set 5 | nikolskoye
# Processing Record 48 of Set 5 | yeppoon
# Processing Record 49 of Set 5 | san policarpo
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | gizo
# Processing Record 4 of Set 6 | villagomez
# Processing Record 5 of Set 6 | poum
# Processing Record 6 of Set 6 | hay river
# Processing Record 7 of Set 6 | oranjestad
# Processing Record 8 of Set 6 | shouguang
# Processing Record 9 of Set 6 | saint anthony
# Processing Record 10 of Set 6 | labuhan
# Processing Record 11 of Set 6 | eston
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | prata
# Processing Record 14 of Set 6 | bathsheba
# Processing Record 15 of Set 6 | masunga
# Processing Record 16 of Set 6 | reconquista
# Processing Record 17 of Set 6 | baykit
# Processing Record 18 of Set 6 | guangyuan
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | araxa
# Processing Record 21 of Set 6 | sao joao da barra
# Processing Record 22 of Set 6 | shache
# Processing Record 23 of Set 6 | gat
# Processing Record 24 of Set 6 | bela
# Processing Record 25 of Set 6 | kebemer
# City not found. Skipping...
# Processing Record 26 of Set 6 | ati
# Processing Record 27 of Set 6 | namibe
# Processing Record 28 of Set 6 | vilyuysk
# Processing Record 29 of Set 6 | jaguarari
# Processing Record 30 of Set 6 | brazzaville
# Processing Record 31 of Set 6 | bandarbeyla
# Processing Record 32 of Set 6 | andenes
# Processing Record 33 of Set 6 | brokopondo
# Processing Record 34 of Set 6 | tasiilaq
# Processing Record 35 of Set 6 | vardo
# Processing Record 36 of Set 6 | houma
# Processing Record 37 of Set 6 | lasa
# Processing Record 38 of Set 6 | iquitos
# Processing Record 39 of Set 6 | yurla
# Processing Record 40 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 6 | cururupu
# Processing Record 42 of Set 6 | marzuq
# Processing Record 43 of Set 6 | samana
# Processing Record 44 of Set 6 | hovd
# Processing Record 45 of Set 6 | vila franca do campo
# Processing Record 46 of Set 6 | havre-saint-pierre
# Processing Record 47 of Set 6 | hinton
# Processing Record 48 of Set 6 | sangeorz-bai
# City not found. Skipping...
# Processing Record 49 of Set 6 | chongwe
# Processing Record 50 of Set 6 | uyuni
# Processing Record 1 of Set 7 | agirish
# Processing Record 2 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 7 | yar-sale
# Processing Record 4 of Set 7 | terme
# Processing Record 5 of Set 7 | te anau
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 8 of Set 7 | qaqortoq
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | bojnurd
# Processing Record 11 of Set 7 | yumen
# Processing Record 12 of Set 7 | sovetskiy
# Processing Record 13 of Set 7 | kita
# Processing Record 14 of Set 7 | price
# Processing Record 15 of Set 7 | bo rai
# Processing Record 16 of Set 7 | tagusao
# Processing Record 17 of Set 7 | tuatapere
# Processing Record 18 of Set 7 | erzin
# Processing Record 19 of Set 7 | marsh harbour
# Processing Record 20 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | lazaro cardenas
# Processing Record 23 of Set 7 | wasilla
# Processing Record 24 of Set 7 | jasper
# Processing Record 25 of Set 7 | kemijarvi
# Processing Record 26 of Set 7 | macusani
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | mildura
# Processing Record 29 of Set 7 | chapais
# Processing Record 30 of Set 7 | rorvik
# Processing Record 31 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 7 | manokwari
# Processing Record 33 of Set 7 | taybad
# Processing Record 34 of Set 7 | ilulissat
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | wladyslawowo
# Processing Record 37 of Set 7 | kushima
# Processing Record 38 of Set 7 | chardara
# Processing Record 39 of Set 7 | matagami
# Processing Record 40 of Set 7 | santo domingo
# Processing Record 41 of Set 7 | raymondville
# Processing Record 42 of Set 7 | nakamura
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | cuajinicuilapa
# Processing Record 45 of Set 7 | bara
# Processing Record 46 of Set 7 | luganville
# Processing Record 47 of Set 7 | salina cruz
# Processing Record 48 of Set 7 | burns lake
# Processing Record 49 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 50 of Set 7 | coihaique
# Processing Record 1 of Set 8 | wlodawa
# Processing Record 2 of Set 8 | sao filipe
# Processing Record 3 of Set 8 | kabalo
# Processing Record 4 of Set 8 | myanaung
# Processing Record 5 of Set 8 | codrington
# Processing Record 6 of Set 8 | matadi
# Processing Record 7 of Set 8 | kieta
# Processing Record 8 of Set 8 | osmena
# Processing Record 9 of Set 8 | futtsu
# Processing Record 10 of Set 8 | sakakah
# Processing Record 11 of Set 8 | areado
# Processing Record 12 of Set 8 | tilichiki
# Processing Record 13 of Set 8 | pocatello
# Processing Record 14 of Set 8 | meridian
# Processing Record 15 of Set 8 | umm lajj
# Processing Record 16 of Set 8 | kattivakkam
# Processing Record 17 of Set 8 | maumere
# Processing Record 18 of Set 8 | rottenmann
# Processing Record 19 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 20 of Set 8 | harlingen
# Processing Record 21 of Set 8 | opuwo
# Processing Record 22 of Set 8 | doka
# Processing Record 23 of Set 8 | villamontes
# Processing Record 24 of Set 8 | lagoa
# Processing Record 25 of Set 8 | bengkulu
# Processing Record 26 of Set 8 | del rio
# Processing Record 27 of Set 8 | cape elizabeth
# City not found. Skipping...
# Processing Record 28 of Set 8 | seoul
# Processing Record 29 of Set 8 | fasa
# Processing Record 30 of Set 8 | saint-pierre
# Processing Record 31 of Set 8 | varhaug
# Processing Record 32 of Set 8 | bang lamung
# Processing Record 33 of Set 8 | walvis bay
# Processing Record 34 of Set 8 | keningau
# Processing Record 35 of Set 8 | riyadh
# Processing Record 36 of Set 8 | kutum
# Processing Record 37 of Set 8 | kolondieba
# Processing Record 38 of Set 8 | isangel
# Processing Record 39 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 8 | oktyabrskiy
# Processing Record 41 of Set 8 | mount isa
# Processing Record 42 of Set 8 | anchorage
# Processing Record 43 of Set 8 | kaina
# Processing Record 44 of Set 8 | smolenka
# Processing Record 45 of Set 8 | guerrero negro
# Processing Record 46 of Set 8 | tadine
# Processing Record 47 of Set 8 | kajaani
# Processing Record 48 of Set 8 | gazanjyk
# Processing Record 49 of Set 8 | la quinta
# Processing Record 50 of Set 8 | qostanay
# Processing Record 1 of Set 9 | dogondoutchi
# Processing Record 2 of Set 9 | port moresby
# Processing Record 3 of Set 9 | banamba
# Processing Record 4 of Set 9 | bonavista
# Processing Record 5 of Set 9 | madimba
# Processing Record 6 of Set 9 | morondava
# Processing Record 7 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 8 of Set 9 | coquimbo
# Processing Record 9 of Set 9 | lodja
# Processing Record 10 of Set 9 | wagga wagga
# Processing Record 11 of Set 9 | llandrindod wells
# Processing Record 12 of Set 9 | berbera
# Processing Record 13 of Set 9 | zyryanka
# Processing Record 14 of Set 9 | hobyo
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | shitanjing
# Processing Record 17 of Set 9 | campbell river
# Processing Record 18 of Set 9 | neryungri
# Processing Record 19 of Set 9 | salamiyah
# Processing Record 20 of Set 9 | kerouane
# Processing Record 21 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 9 | anloga
# Processing Record 23 of Set 9 | zavodskoy
# Processing Record 24 of Set 9 | eyl
# Processing Record 25 of Set 9 | salaga
# Processing Record 26 of Set 9 | brindisi
# Processing Record 27 of Set 9 | kampot
# Processing Record 28 of Set 9 | tiznit
# Processing Record 29 of Set 9 | tabou
# Processing Record 30 of Set 9 | tateyama
# Processing Record 31 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 32 of Set 9 | evensk
# Processing Record 33 of Set 9 | kozlovo
# Processing Record 34 of Set 9 | kinel
# Processing Record 35 of Set 9 | vokhtoga
# Processing Record 36 of Set 9 | khuzhir
# Processing Record 37 of Set 9 | fenyi
# Processing Record 38 of Set 9 | sinjah
# City not found. Skipping...
# Processing Record 39 of Set 9 | miramar
# Processing Record 40 of Set 9 | olot
# Processing Record 41 of Set 9 | tual
# Processing Record 42 of Set 9 | vyartsilya
# Processing Record 43 of Set 9 | sosnogorsk
# Processing Record 44 of Set 9 | senno
# Processing Record 45 of Set 9 | tucuman
# Processing Record 46 of Set 9 | vestmanna
# Processing Record 47 of Set 9 | ivanava
# Processing Record 48 of Set 9 | canton
# Processing Record 49 of Set 9 | bahar
# Processing Record 50 of Set 9 | inuvik
# Processing Record 1 of Set 10 | sikonge
# Processing Record 2 of Set 10 | yatou
# Processing Record 3 of Set 10 | mayumba
# Processing Record 4 of Set 10 | sinnamary
# Processing Record 5 of Set 10 | bukama
# Processing Record 6 of Set 10 | macapa
# Processing Record 7 of Set 10 | mata
# Processing Record 8 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 10 | cockburn town
# Processing Record 10 of Set 10 | morant bay
# Processing Record 11 of Set 10 | jamame
# Processing Record 12 of Set 10 | san jeronimo
# Processing Record 13 of Set 10 | darbhanga
# Processing Record 14 of Set 10 | cap malheureux
# Processing Record 15 of Set 10 | shimoda
# Processing Record 16 of Set 10 | qeshm
# Processing Record 17 of Set 10 | sept-iles
# Processing Record 18 of Set 10 | tagaytay
# Processing Record 19 of Set 10 | gold coast
# Processing Record 20 of Set 10 | huarmey
# Processing Record 21 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 22 of Set 10 | husavik
# Processing Record 23 of Set 10 | saint george
# Processing Record 24 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 10 | serenje
# Processing Record 26 of Set 10 | kandrian
# Processing Record 27 of Set 10 | myre
# Processing Record 28 of Set 10 | molochnoye
# Processing Record 29 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 30 of Set 10 | ambilobe
# Processing Record 31 of Set 10 | shahrud
# Processing Record 32 of Set 10 | alice springs
# Processing Record 33 of Set 10 | hatillo
# Processing Record 34 of Set 10 | takoradi
# Processing Record 35 of Set 10 | mahajanga
# Processing Record 36 of Set 10 | yabelo
# Processing Record 37 of Set 10 | victoria
# Processing Record 38 of Set 10 | harper
# Processing Record 39 of Set 10 | banyo
# Processing Record 40 of Set 10 | kyshtovka
# Processing Record 41 of Set 10 | heilbron
# Processing Record 42 of Set 10 | phirangipuram
# Processing Record 43 of Set 10 | culpeper
# Processing Record 44 of Set 10 | klerksdorp
# Processing Record 45 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 10 | naze
# Processing Record 47 of Set 10 | laibin
# Processing Record 48 of Set 10 | havelock
# Processing Record 49 of Set 10 | zaragoza
# Processing Record 50 of Set 10 | mananara
# Processing Record 1 of Set 11 | broome
# Processing Record 2 of Set 11 | road town
# Processing Record 3 of Set 11 | chilca
# Processing Record 4 of Set 11 | zhigansk
# Processing Record 5 of Set 11 | shenjiamen
# Processing Record 6 of Set 11 | teya
# Processing Record 7 of Set 11 | zhuanghe
# Processing Record 8 of Set 11 | stettler
# Processing Record 9 of Set 11 | kanodar
# Processing Record 10 of Set 11 | ostrovnoy
# Processing Record 11 of Set 11 | pangnirtung
# Processing Record 12 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 11 | solnechnyy
# Processing Record 14 of Set 11 | mahibadhoo
# Processing Record 15 of Set 11 | itarema
# Processing Record 16 of Set 11 | dongsheng
# Processing Record 17 of Set 11 | mahon
# Processing Record 18 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 19 of Set 11 | mount airy
# Processing Record 20 of Set 11 | mallama
# City not found. Skipping...
# Processing Record 21 of Set 11 | makurdi
# Processing Record 22 of Set 11 | marshall
# Processing Record 23 of Set 11 | springbok
# Processing Record 24 of Set 11 | port macquarie
# Processing Record 25 of Set 11 | kubanskiy
# Processing Record 26 of Set 11 | hirado
# Processing Record 27 of Set 11 | berlevag
# Processing Record 28 of Set 11 | adre
# Processing Record 29 of Set 11 | staryy nadym
# Processing Record 30 of Set 11 | indramayu
# Processing Record 31 of Set 11 | ikot ekpene
# Processing Record 32 of Set 11 | kaeo
# Processing Record 33 of Set 11 | beauvais
# Processing Record 34 of Set 11 | noumea
# Processing Record 35 of Set 11 | mikkeli
# Processing Record 36 of Set 11 | itoman
# Processing Record 37 of Set 11 | formosa
# Processing Record 38 of Set 11 | leh
# Processing Record 39 of Set 11 | wau
# Processing Record 40 of Set 11 | cabedelo
# Processing Record 41 of Set 11 | kloulklubed
# Processing Record 42 of Set 11 | beoumi
# Processing Record 43 of Set 11 | pipri
# Processing Record 44 of Set 11 | rawson
# Processing Record 45 of Set 11 | xining
# Processing Record 46 of Set 11 | tovuz
# Processing Record 47 of Set 11 | les herbiers
# Processing Record 48 of Set 11 | neuquen
# Processing Record 49 of Set 11 | little baguio
# Processing Record 50 of Set 11 | zigos
# Processing Record 1 of Set 12 | leshukonskoye
# Processing Record 2 of Set 12 | miami
# Processing Record 3 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 12 | lompoc
# Processing Record 5 of Set 12 | burnie
# Processing Record 6 of Set 12 | kokopo
# Processing Record 7 of Set 12 | tandalti
# Processing Record 8 of Set 12 | tulum
# Processing Record 9 of Set 12 | nova olinda do norte
# Processing Record 10 of Set 12 | jimo
# Processing Record 11 of Set 12 | dunmore east
# Processing Record 12 of Set 12 | savelugu
# Processing Record 13 of Set 12 | clara
# Processing Record 14 of Set 12 | wakkanai
# Processing Record 15 of Set 12 | faya
# Processing Record 16 of Set 12 | la asuncion
# Processing Record 17 of Set 12 | taoudenni
# Processing Record 18 of Set 12 | adrar
# Processing Record 19 of Set 12 | sola
# Processing Record 20 of Set 12 | batticaloa
# Processing Record 21 of Set 12 | iwanai
# Processing Record 22 of Set 12 | emerald
# Processing Record 23 of Set 12 | akonolinga
# Processing Record 24 of Set 12 | san juan
# Processing Record 25 of Set 12 | chute-aux-outardes
# Processing Record 26 of Set 12 | manado
# Processing Record 27 of Set 12 | bantou
# Processing Record 28 of Set 12 | portales
# Processing Record 29 of Set 12 | pangody
# Processing Record 30 of Set 12 | nabire
# Processing Record 31 of Set 12 | high level
# Processing Record 32 of Set 12 | nelson bay
# Processing Record 33 of Set 12 | uige
# Processing Record 34 of Set 12 | mnogovershinnyy
# Processing Record 35 of Set 12 | college
# Processing Record 36 of Set 12 | christchurch
# Processing Record 37 of Set 12 | erenhot
# Processing Record 38 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 12 | dudinka
# Processing Record 40 of Set 12 | bachaquero
# Processing Record 41 of Set 12 | kanigoro
# Processing Record 42 of Set 12 | hambantota
# Processing Record 43 of Set 12 | oranjemund
# Processing Record 44 of Set 12 | sibu
# Processing Record 45 of Set 12 | tomatlan
# Processing Record 46 of Set 12 | magistralnyy
# Processing Record 47 of Set 12 | fort nelson
# Processing Record 48 of Set 12 | svetlyy
# Processing Record 49 of Set 12 | los andes
# Processing Record 50 of Set 12 | sorong
# Processing Record 1 of Set 13 | hofn
# Processing Record 2 of Set 13 | dingle
# Processing Record 3 of Set 13 | viedma
# Processing Record 4 of Set 13 | kurilsk
# Processing Record 5 of Set 13 | nemuro
# Processing Record 6 of Set 13 | ulladulla
# Processing Record 7 of Set 13 | teahupoo
# Processing Record 8 of Set 13 | de-kastri
# Processing Record 9 of Set 13 | portland
# Processing Record 10 of Set 13 | los llanos de aridane
# Processing Record 11 of Set 13 | asyut
# Processing Record 12 of Set 13 | camamu
# Processing Record 13 of Set 13 | esfarayen
# Processing Record 14 of Set 13 | raga
# Processing Record 15 of Set 13 | vila velha
# Processing Record 16 of Set 13 | dafeng
# Processing Record 17 of Set 13 | margate
# Processing Record 18 of Set 13 | ianca
# Processing Record 19 of Set 13 | canete
# Processing Record 20 of Set 13 | karlovo
# Processing Record 21 of Set 13 | darfo
# Processing Record 22 of Set 13 | ingham
# Processing Record 23 of Set 13 | qinggang
# Processing Record 24 of Set 13 | lugovoy
# Processing Record 25 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 26 of Set 13 | tommot
# Processing Record 27 of Set 13 | canutama
# Processing Record 28 of Set 13 | sorland
# Processing Record 29 of Set 13 | pakxe
# Processing Record 30 of Set 13 | selfoss
# Processing Record 31 of Set 13 | mitu
# Processing Record 32 of Set 13 | muravlenko
# Processing Record 33 of Set 13 | tamandare
# Processing Record 34 of Set 13 | nuuk
# Processing Record 35 of Set 13 | pandan
# Processing Record 36 of Set 13 | sao felix do xingu
# Processing Record 37 of Set 13 | seabra
# Processing Record 38 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 13 | gamba
# Processing Record 40 of Set 13 | pineville
# Processing Record 41 of Set 13 | nantucket
# Processing Record 42 of Set 13 | palu
# Processing Record 43 of Set 13 | cervo
# Processing Record 44 of Set 13 | fortuna foothills
# Processing Record 45 of Set 13 | hirara
# Processing Record 46 of Set 13 | livramento
# Processing Record 47 of Set 13 | khandbari
# Processing Record 48 of Set 13 | flagstaff
# Processing Record 49 of Set 13 | srandakan
# Processing Record 50 of Set 13 | daulatpur
# Processing Record 1 of Set 14 | beringovskiy
# Processing Record 2 of Set 14 | kudahuvadhoo
# Processing Record 3 of Set 14 | timra
# Processing Record 4 of Set 14 | kokstad
# Processing Record 5 of Set 14 | san felipe
# Processing Record 6 of Set 14 | belaya gora
# Processing Record 7 of Set 14 | sharlyk
# Processing Record 8 of Set 14 | namatanai
# Processing Record 9 of Set 14 | campbellton
# Processing Record 10 of Set 14 | bulgan
# Processing Record 11 of Set 14 | redcliffe
# Processing Record 12 of Set 14 | markala
# Processing Record 13 of Set 14 | koindu
# Processing Record 14 of Set 14 | orlovskiy
# Processing Record 15 of Set 14 | visnes
# Processing Record 16 of Set 14 | namioka
# Processing Record 17 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 14 | chabahar
# Processing Record 19 of Set 14 | taltal
# Processing Record 20 of Set 14 | belmonte
# Processing Record 21 of Set 14 | krasnoselkup
# Processing Record 22 of Set 14 | soe
# Processing Record 23 of Set 14 | klyuchi
# Processing Record 24 of Set 14 | kununurra
# Processing Record 25 of Set 14 | namtsy
# Processing Record 26 of Set 14 | dakar
# Processing Record 27 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 14 | monzon
# Processing Record 29 of Set 14 | mirnyy
# Processing Record 30 of Set 14 | balbalan
# Processing Record 31 of Set 14 | saiki
# Processing Record 32 of Set 14 | surgut
# Processing Record 33 of Set 14 | shakawe
# Processing Record 34 of Set 14 | uribia
# Processing Record 35 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 14 | shingu
# Processing Record 37 of Set 14 | neropolis
# Processing Record 38 of Set 14 | san quintin
# Processing Record 39 of Set 14 | bama
# Processing Record 40 of Set 14 | santa cruz del sur
# Processing Record 41 of Set 14 | weligama
# Processing Record 42 of Set 14 | cotonou
# Processing Record 43 of Set 14 | purpe
# Processing Record 44 of Set 14 | verkhnevilyuysk
# Processing Record 45 of Set 14 | iranshahr
# Processing Record 46 of Set 14 | covington
# Processing Record 47 of Set 14 | ryotsu
# Processing Record 48 of Set 14 | mana
# Processing Record 49 of Set 14 | kropotkin
# Processing Record 50 of Set 14 | empalme
# Processing Record 1 of Set 15 | sanguem
# Processing Record 2 of Set 15 | togur
# Processing Record 3 of Set 15 | hokitika
# Processing Record 4 of Set 15 | malatya
# Processing Record 5 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 6 of Set 15 | piacabucu
# Processing Record 7 of Set 15 | nome
# Processing Record 8 of Set 15 | zhaodong
# Processing Record 9 of Set 15 | manbij
# Processing Record 10 of Set 15 | adeje
# Processing Record 11 of Set 15 | marinette
# Processing Record 12 of Set 15 | ystad
# Processing Record 13 of Set 15 | chigorodo
# Processing Record 14 of Set 15 | katobu
# Processing Record 15 of Set 15 | mackay
# Processing Record 16 of Set 15 | pinillos
# Processing Record 17 of Set 15 | muromtsevo
# Processing Record 18 of Set 15 | chatra
# Processing Record 19 of Set 15 | mapiri
# Processing Record 20 of Set 15 | kasongo
# Processing Record 21 of Set 15 | mandalgovi
# Processing Record 22 of Set 15 | pierre
# Processing Record 23 of Set 15 | nyurba
# Processing Record 24 of Set 15 | sur
# Processing Record 25 of Set 15 | paamiut
# Processing Record 26 of Set 15 | villa carlos paz
# Processing Record 27 of Set 15 | keti bandar
# Processing Record 28 of Set 15 | luziania
# Processing Record 29 of Set 15 | milledgeville
# Processing Record 30 of Set 15 | champerico
# Processing Record 31 of Set 15 | komsomolskiy
# Processing Record 32 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 15 | gunjur
# Processing Record 34 of Set 15 | sterling
# Processing Record 35 of Set 15 | magnitogorsk
# Processing Record 36 of Set 15 | goundam
# Processing Record 37 of Set 15 | baghdad
# Processing Record 38 of Set 15 | dongning
# Processing Record 39 of Set 15 | mansoa
# Processing Record 40 of Set 15 | notre-dame-du-lac
# Processing Record 41 of Set 15 | acarau
# Processing Record 42 of Set 15 | anton lizardo
# Processing Record 43 of Set 15 | tecoanapa
# Processing Record 44 of Set 15 | osuna
# Processing Record 45 of Set 15 | hamilton
# Processing Record 46 of Set 15 | maningrida
# Processing Record 47 of Set 15 | westport
# Processing Record 48 of Set 15 | batemans bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     37.51        75           0
# 1         Kuusamo      FI  65.9667   29.1833     48.24       100           0
# 2       Gladstone      AU -23.8500  151.2500     69.73        56           0
# 3  Saint-Philippe      RE -21.3585   55.7679     65.21        76          39
# 4      Whitehorse      CA  60.7161 -135.0538     56.17        82         100
# 5           Tiksi      RU  71.6872  128.8694     49.17        72          40
# 6      San Andres      CO  12.5847  -81.7006     84.22        74          40
# 7          Hobart      AU -42.8794  147.3294     53.26        95          75
# 8         Rikitea      PF -23.1203 -134.9692     75.40        80          33
# 9     Yellowknife      CA  62.4560 -114.3525     61.32        88          75
#
#    Wind Speed          Current Description
# 0        9.22                    clear sky
# 1        3.44                    clear sky
# 2       10.36                    clear sky
# 3        6.76             scattered clouds
# 4        8.05              overcast clouds
# 5        2.98             scattered clouds
# 6       10.36             scattered clouds
# 7        5.75                broken clouds
# 8       15.75             scattered clouds
# 9       10.36  light intensity shower rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
